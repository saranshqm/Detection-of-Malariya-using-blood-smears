# %%
from __future__ import absolute_import, division, print_function
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import os
#print(os.listdir("../input/cell_images/cell_images"))

# %%
print(os.listdir('D:\data analysis\kaggle\cell-images-for-detecting-malaria\cell_images'))
# Out:
# ['Parasitized', 'Uninfected']

# %%
infected = os.listdir("D:\\data analysis\\kaggle\\cell-images-for-detecting-malaria\\cell_images\Parasitized") 
uninfected = os.listdir("D:\\data analysis\\kaggle\\cell-images-for-detecting-malaria\\cell_images\\Uninfected")

# %%
data = []
labels = []

for i in infected:
    try:
    
        image = cv2.imread("D:\\data analysis\\kaggle\\cell-images-for-detecting-malaria\\cell_images\\Parasitized\\"+i)
        image_array = Image.fromarray(image , 'RGB')
        resize_img = image_array.resize((50 , 50))
        rotated45 = resize_img.rotate(45)
        rotated75 = resize_img.rotate(75)
        blur = cv2.blur(np.array(resize_img) ,(10,10))
        data.append(np.array(resize_img))
        data.append(np.array(rotated45))
        data.append(np.array(rotated75))
        data.append(np.array(blur))
        labels.append(1)
        labels.append(1)
        labels.append(1)
        labels.append(1)
        
    except AttributeError:
        print('')
    
for u in uninfected:
    try:
        
        image = cv2.imread("D:\\data analysis\\kaggle\\cell-images-for-detecting-malaria\\cell_images\\Uninfected\\"+u)
        image_array = Image.fromarray(image , 'RGB')
        resize_img = image_array.resize((50 , 50))
        rotated45 = resize_img.rotate(45)
        rotated75 = resize_img.rotate(75)
        data.append(np.array(resize_img))
        data.append(np.array(rotated45))
        data.append(np.array(rotated75))
        labels.append(0)
        labels.append(0)
        labels.append(0)
        
    except AttributeError:
        print('')

# %%
cells = np.array(data)
labels = np.array(labels)

np.save('Cells' , cells)
np.save('Labels' , labels)

# %%
plt.figure(1 , figsize = (15 , 9))
n = 0 
for i in range(49):
    n += 1 
    r = np.random.randint(0 , cells.shape[0] , 1)
    plt.subplot(7 , 7 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    plt.imshow(cells[r[0]])
    plt.title('{} : {}'.format('Infected' if labels[r[0]] == 1 else 'Unifected' ,
                               labels[r[0]]) )
    plt.xticks([]) , plt.yticks([])
    
plt.show()

# %%
plt.figure(1, figsize = (15 , 7))
plt.subplot(1 , 2 , 1)
plt.imshow(cells[0])
plt.title('Infected Cell')
plt.xticks([]) , plt.yticks([])

plt.subplot(1 , 2 , 2)
plt.imshow(cells[60000])
plt.title('Uninfected Cell')
plt.xticks([]) , plt.yticks([])

plt.show()

# %%
n = np.arange(cells.shape[0])
np.random.shuffle(n)
cells = cells[n]
labels = labels[n]

# %%
cells = cells.astype(np.float32)
labels = labels.astype(np.int32)
cells = cells/255

# %%
from sklearn.model_selection import train_test_split

train_x , x , train_y , y = train_test_split(cells , labels , 
                                            test_size = 0.2 ,
                                            random_state = 111)

eval_x , test_x , eval_y , test_y = train_test_split(x , y , 
                                                    test_size = 0.5 , 
                                                    random_state = 111)

# %%
plt.figure(1 , figsize = (15 ,5))
n = 0 
for z , j in zip([train_y , eval_y , test_y] , ['train labels','eval labels','test labels']):
    n += 1
    plt.subplot(1 , 3  , n)
    sns.countplot(x = z )
    plt.title(j)
plt.show()

# %%
print('train data shape {} ,eval data shape {} , test data shape {}'.format(train_x.shape,
                                                                           eval_x.shape ,
                                                                           test_x.shape))
# Out:
# train data shape (77162, 50, 50, 3) ,eval data shape (9645, 50, 50, 3) , test data shape (9646, 50, 50, 3)

# %%
tf.reset_default_graph()
def cnn_model_fn(features , labels , mode):
    input_layers = tf.reshape(features['x'] , [-1 , 50 , 50 ,3])    
    conv1 = tf.layers.conv2d(
        inputs = input_layers , 
        filters = 50 , 
        kernel_size = [7 , 7],
        padding = 'same',
        activation = tf.nn.relu
        ) 
    
    
    conv2 = tf.layers.conv2d(
        inputs = conv1, 
        filters = 90,
        kernel_size = [3 , 3],
        padding = 'valid',
        activation = tf.nn.relu
        )

        
    conv3 = tf.layers.conv2d(
        inputs = conv2 ,
        filters = 10,
        kernel_size = [5 , 5],
        padding = 'same', 
        activation = tf.nn.relu
        )
    
    pool1 = tf.layers.max_pooling2d(inputs = conv3 , pool_size = [2 , 2] ,
                                    strides = 2 )
    conv4 = tf.layers.conv2d(
        inputs = pool1 ,
        filters = 5,
        kernel_size = [3 , 3],
        padding = 'same', 
        activation = tf.nn.relu
        )

    pool2 = tf.layers.max_pooling2d(inputs = conv4 , pool_size = [2 , 2] ,
                                    strides = 2 , padding = 'same')
    
    pool2_flatten = tf.layers.flatten(pool2)
    fc1 = tf.layers.dense(
        inputs = pool2_flatten,
        units = 2000,
        activation = tf.nn.relu
        )
    fc2 = tf.layers.dense(
        inputs = fc1,
        units = 1000,
        activation = tf.nn.relu
        )
    fc3 = tf.layers.dense(
        inputs = fc2 , 
        units = 500 ,
        activation = tf.nn.relu
        )
    logits = tf.layers.dense(
        inputs = fc3 ,
        units = 2
        )
    
    predictions = {
        'classes': tf.argmax(input = logits , axis = 1),
        'probabilities': tf.nn.softmax(logits , name = 'softmax_tensor')
    }
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode = mode , 
                                          predictions = predictions)
    
    loss = tf.losses.sparse_softmax_cross_entropy(labels = labels , 
                                                 logits = logits)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.001)
        train_op = optimizer.minimize(loss = loss , 
                                      global_step = tf.train.get_global_step())
        
        return tf.estimator.EstimatorSpec(mode = mode , 
                                            loss = loss , 
                                            train_op = train_op 
                                           )
    eval_metric_op = {'accuracy' : tf.metrics.accuracy(labels = labels ,
                                         predictions =  predictions['classes'])}
    
    return tf.estimator.EstimatorSpec(mode = mode , 
                                      loss = loss , 
                                      eval_metric_ops = eval_metric_op)

# %%
malaria_detector = tf.estimator.Estimator(model_fn = cnn_model_fn , 
                                         model_dir = '/tmp/modelchkpt')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/modelchkpt', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001C1691D2888>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
tensors_to_log = {'probabilities':'softmax_tensor'}
logging_hook = tf.train.LoggingTensorHook(
    tensors = tensors_to_log , every_n_iter = 50 
    )

# %%
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x = {'x': train_x},
    y = train_y,
    batch_size = 100 , 
    num_epochs = None , 
    shuffle = True
    )
malaria_detector.train(input_fn = train_input_fn , steps = 1 , hooks = [logging_hook])
# Out:
# WARNING:tensorflow:From C:\Users\SARANSH\Anaconda3\envs\saransh\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From C:\Users\SARANSH\Anaconda3\envs\saransh\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From C:\Users\SARANSH\Anaconda3\envs\saransh\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-41-424ddd03141c>:9: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From C:\Users\SARANSH\Anaconda3\envs\saransh\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C168FBDE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C168FBDE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C168FBDE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C168FBDE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C168FBDE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C168FBDE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C168FBDE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C168FBDE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1691BE448>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1691BE448>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1691BE448>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1691BE448>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From <ipython-input-41-424ddd03141c>:31: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1691B4D88>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1691B4D88>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1691B4D88>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1691B4D88>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1466EDE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1466EDE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1466EDE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1466EDE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1466EDE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1466EDE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1466EDE48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1466EDE48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From <ipython-input-41-424ddd03141c>:43: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C168FC2E08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C168FC2E08>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C168FC2E08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C168FC2E08>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From <ipython-input-41-424ddd03141c>:47: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16933E208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16933E208>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16933E208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16933E208>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C16908E0C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From C:\Users\SARANSH\Anaconda3\envs\saransh\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\Users\SARANSH\Anaconda3\envs\saransh\lib\site-packages\tensorflow\python\training\monitored_session.py:875: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/modelchkpt\model.ckpt.
# INFO:tensorflow:probabilities = [[0.49909467 0.50090533]
#  [0.49839547 0.50160456]
#  [0.49803305 0.50196695]
#  [0.4985574  0.5014426 ]
#  [0.4972202  0.5027798 ]
#  [0.49818507 0.50181496]
#  [0.4963493  0.50365067]
#  [0.49800515 0.50199485]
#  [0.49869582 0.50130415]
#  [0.49848446 0.50151557]
#  [0.49702358 0.50297636]
#  [0.49809355 0.5019064 ]
#  [0.4982271  0.50177294]
#  [0.50215936 0.4978406 ]
#  [0.49937052 0.5006294 ]
#  [0.49913126 0.50086874]
#  [0.49884224 0.50115776]
#  [0.5006376  0.49936244]
#  [0.4979904  0.5020096 ]
#  [0.5009173  0.49908268]
#  [0.5005221  0.49947792]
#  [0.49654138 0.5034586 ]
#  [0.4981835  0.5018165 ]
#  [0.49827492 0.5017251 ]
#  [0.49849162 0.5015084 ]
#  [0.4972813  0.50271875]
#  [0.49773172 0.50226825]
#  [0.49689084 0.50310916]
#  [0.50050175 0.49949822]
#  [0.50005615 0.49994385]
#  [0.49770057 0.5022994 ]
#  [0.500114   0.49988598]
#  [0.49724388 0.5027561 ]
#  [0.4992419  0.5007581 ]
#  [0.5008751  0.4991249 ]
#  [0.49859527 0.50140476]
#  [0.49834308 0.5016569 ]
#  [0.49997804 0.50002193]
#  [0.5008866  0.49911338]
#  [0.49716598 0.502834  ]
#  [0.4998726  0.50012743]
#  [0.497919   0.50208104]
#  [0.50200343 0.4979966 ]
#  [0.4991896  0.50081044]
#  [0.5004864  0.49951366]
#  [0.49894518 0.5010548 ]
#  [0.50057065 0.49942932]
#  [0.49846935 0.5015306 ]
#  [0.49876648 0.5012335 ]
#  [0.49753588 0.5024641 ]
#  [0.49802217 0.50197786]
#  [0.49922654 0.5007735 ]
#  [0.5009113  0.49908873]
#  [0.49906585 0.5009342 ]
#  [0.49886715 0.50113285]
#  [0.49770448 0.50229555]
#  [0.4980988  0.5019012 ]
#  [0.49905938 0.5009406 ]
#  [0.4984371  0.5015629 ]
#  [0.4989031  0.50109684]
#  [0.4996807  0.5003193 ]
#  [0.4988661  0.50113386]
#  [0.50047255 0.49952742]
#  [0.5011615  0.4988385 ]
#  [0.4976134  0.5023866 ]
#  [0.498067   0.50193304]
#  [0.49913964 0.50086033]
#  [0.4992917  0.5007083 ]
#  [0.503101   0.496899  ]
#  [0.49939263 0.5006074 ]
#  [0.5033288  0.49667114]
#  [0.5003539  0.4996461 ]
#  [0.4987982  0.50120175]
#  [0.49851987 0.5014801 ]
#  [0.50115955 0.49884048]
#  [0.49616283 0.50383717]
#  [0.49828547 0.5017145 ]
#  [0.49594972 0.5040503 ]
#  [0.49968684 0.50031316]
#  [0.49889195 0.50110805]
#  [0.4983826  0.5016174 ]
#  [0.50080115 0.49919885]
#  [0.49777192 0.5022281 ]
#  [0.49905604 0.50094396]
#  [0.49840775 0.5015922 ]
#  [0.5001761  0.4998239 ]
#  [0.4986964  0.5013036 ]
#  [0.49847716 0.5015229 ]
#  [0.50256425 0.49743578]
#  [0.5021382  0.49786177]
#  [0.5013213  0.49867862]
#  [0.5008559  0.49914408]
#  [0.49726805 0.502732  ]
#  [0.49778652 0.50221354]
#  [0.49938276 0.5006172 ]
#  [0.49810737 0.5018926 ]
#  [0.4973849  0.50261503]
#  [0.49780935 0.50219065]
#  [0.4995845  0.5004155 ]
#  [0.49995622 0.50004375]]
# INFO:tensorflow:loss = 0.6926469, step = 0
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/modelchkpt\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.6926469.

# %%
malaria_detector.train(input_fn = train_input_fn , steps = 10000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1466F5A48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1466F5A48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1466F5A48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1466F5A48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1691C0388>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1691C0388>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1691C0388>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1691C0388>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1693E66C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1693E66C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1693E66C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1693E66C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1691DD0C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1691DD0C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1691DD0C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C1691DD0C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1091CD348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1091CD348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1091CD348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C1091CD348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C168FF3088>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C168FF3088>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C168FF3088>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C168FF3088>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C169940988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C169940988>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C169940988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C169940988>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C249BFD1C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C249BFD1C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C249BFD1C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C249BFD1C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C14668CCC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From C:\Users\SARANSH\Anaconda3\envs\saransh\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /tmp/modelchkpt\model.ckpt-1
# WARNING:tensorflow:From C:\Users\SARANSH\Anaconda3\envs\saransh\lib\site-packages\tensorflow\python\training\saver.py:1066: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/modelchkpt\model.ckpt.
# INFO:tensorflow:loss = 0.6928315, step = 1
# INFO:tensorflow:global_step/sec: 25.0029
# INFO:tensorflow:loss = 0.6911785, step = 101 (4.002 sec)
# INFO:tensorflow:global_step/sec: 25.4966
# INFO:tensorflow:loss = 0.6876833, step = 201 (3.920 sec)
# INFO:tensorflow:global_step/sec: 25.488
# INFO:tensorflow:loss = 0.6881681, step = 301 (3.922 sec)
# INFO:tensorflow:global_step/sec: 25.3427
# INFO:tensorflow:loss = 0.67411494, step = 401 (3.947 sec)
# INFO:tensorflow:global_step/sec: 25.426
# INFO:tensorflow:loss = 0.6861396, step = 501 (3.932 sec)
# INFO:tensorflow:global_step/sec: 25.2286
# INFO:tensorflow:loss = 0.66675377, step = 601 (3.964 sec)
# INFO:tensorflow:global_step/sec: 25.1855
# INFO:tensorflow:loss = 0.6943413, step = 701 (3.973 sec)
# INFO:tensorflow:global_step/sec: 25.2261
# INFO:tensorflow:loss = 0.67213356, step = 801 (3.962 sec)
# INFO:tensorflow:global_step/sec: 25.1208
# INFO:tensorflow:loss = 0.6869273, step = 901 (3.983 sec)
# INFO:tensorflow:global_step/sec: 25.13
# INFO:tensorflow:loss = 0.69296384, step = 1001 (3.977 sec)
# INFO:tensorflow:global_step/sec: 24.6749
# INFO:tensorflow:loss = 0.67700803, step = 1101 (4.056 sec)
# INFO:tensorflow:global_step/sec: 24.6993
# INFO:tensorflow:loss = 0.67758214, step = 1201 (4.047 sec)
# INFO:tensorflow:global_step/sec: 25.0213
# INFO:tensorflow:loss = 0.68156105, step = 1301 (3.998 sec)
# INFO:tensorflow:global_step/sec: 24.8821
# INFO:tensorflow:loss = 0.68273133, step = 1401 (4.017 sec)
# INFO:tensorflow:global_step/sec: 24.7125
# INFO:tensorflow:loss = 0.6659183, step = 1501 (4.048 sec)
# INFO:tensorflow:global_step/sec: 24.759
# INFO:tensorflow:loss = 0.67046976, step = 1601 (4.041 sec)
# INFO:tensorflow:global_step/sec: 24.8402
# INFO:tensorflow:loss = 0.6822845, step = 1701 (4.025 sec)
# INFO:tensorflow:global_step/sec: 24.8731
# INFO:tensorflow:loss = 0.6638879, step = 1801 (4.020 sec)
# INFO:tensorflow:global_step/sec: 25.0111
# INFO:tensorflow:loss = 0.65072846, step = 1901 (3.996 sec)
# INFO:tensorflow:global_step/sec: 24.8378
# INFO:tensorflow:loss = 0.6541239, step = 2001 (4.029 sec)
# INFO:tensorflow:global_step/sec: 24.8684
# INFO:tensorflow:loss = 0.6459702, step = 2101 (4.019 sec)
# INFO:tensorflow:global_step/sec: 24.6967
# INFO:tensorflow:loss = 0.6335169, step = 2201 (4.048 sec)
# INFO:tensorflow:global_step/sec: 24.6358
# INFO:tensorflow:loss = 0.64655274, step = 2301 (4.061 sec)
# INFO:tensorflow:global_step/sec: 24.7813
# INFO:tensorflow:loss = 0.63921326, step = 2401 (4.034 sec)
# INFO:tensorflow:global_step/sec: 24.6542
# INFO:tensorflow:loss = 0.6472043, step = 2501 (4.057 sec)
# INFO:tensorflow:global_step/sec: 24.6946
# INFO:tensorflow:loss = 0.6533304, step = 2601 (4.047 sec)
# INFO:tensorflow:global_step/sec: 24.6736
# INFO:tensorflow:loss = 0.6233934, step = 2701 (4.053 sec)
# INFO:tensorflow:global_step/sec: 24.4717
# INFO:tensorflow:loss = 0.5858017, step = 2801 (4.086 sec)
# INFO:tensorflow:global_step/sec: 24.4371
# INFO:tensorflow:loss = 0.67291915, step = 2901 (4.094 sec)
# INFO:tensorflow:global_step/sec: 24.5946
# INFO:tensorflow:loss = 0.690306, step = 3001 (4.064 sec)
# INFO:tensorflow:global_step/sec: 24.829
# INFO:tensorflow:loss = 0.64085597, step = 3101 (4.028 sec)
# INFO:tensorflow:global_step/sec: 24.6879
# INFO:tensorflow:loss = 0.5961207, step = 3201 (4.052 sec)
# INFO:tensorflow:global_step/sec: 24.7983
# INFO:tensorflow:loss = 0.6009292, step = 3301 (4.033 sec)
# INFO:tensorflow:global_step/sec: 24.8813
# INFO:tensorflow:loss = 0.5803381, step = 3401 (4.018 sec)
# INFO:tensorflow:global_step/sec: 24.7403
# INFO:tensorflow:loss = 0.56078035, step = 3501 (4.058 sec)
# INFO:tensorflow:global_step/sec: 24.4478
# INFO:tensorflow:loss = 0.66947645, step = 3601 (4.077 sec)
# INFO:tensorflow:global_step/sec: 24.4819
# INFO:tensorflow:loss = 0.5509628, step = 3701 (4.085 sec)
# INFO:tensorflow:global_step/sec: 24.6081
# INFO:tensorflow:loss = 0.56485665, step = 3801 (4.064 sec)
# INFO:tensorflow:global_step/sec: 24.6661
# INFO:tensorflow:loss = 0.5201723, step = 3901 (4.054 sec)
# INFO:tensorflow:global_step/sec: 24.6314
# INFO:tensorflow:loss = 0.62230307, step = 4001 (4.058 sec)
# INFO:tensorflow:global_step/sec: 24.5542
# INFO:tensorflow:loss = 0.63371825, step = 4101 (4.075 sec)
# INFO:tensorflow:global_step/sec: 24.7696
# INFO:tensorflow:loss = 0.62029594, step = 4201 (4.035 sec)
# INFO:tensorflow:global_step/sec: 24.6408
# INFO:tensorflow:loss = 0.5483479, step = 4301 (4.060 sec)
# INFO:tensorflow:global_step/sec: 24.6425
# INFO:tensorflow:loss = 0.5133871, step = 4401 (4.057 sec)
# INFO:tensorflow:global_step/sec: 24.7305
# INFO:tensorflow:loss = 0.56163675, step = 4501 (4.043 sec)
# INFO:tensorflow:global_step/sec: 24.6357
# INFO:tensorflow:loss = 0.52258134, step = 4601 (4.059 sec)
# INFO:tensorflow:global_step/sec: 24.4306
# INFO:tensorflow:loss = 0.5270929, step = 4701 (4.094 sec)
# INFO:tensorflow:global_step/sec: 24.6845
# INFO:tensorflow:loss = 0.51430064, step = 4801 (4.050 sec)
# INFO:tensorflow:global_step/sec: 24.4882
# INFO:tensorflow:loss = 0.6179807, step = 4901 (4.084 sec)
# INFO:tensorflow:global_step/sec: 24.3881
# INFO:tensorflow:loss = 0.6693859, step = 5001 (4.102 sec)
# INFO:tensorflow:global_step/sec: 24.5122
# INFO:tensorflow:loss = 0.5994203, step = 5101 (4.079 sec)
# INFO:tensorflow:global_step/sec: 24.5403
# INFO:tensorflow:loss = 0.50335085, step = 5201 (4.074 sec)
# INFO:tensorflow:global_step/sec: 24.6921
# INFO:tensorflow:loss = 0.54972917, step = 5301 (4.049 sec)
# INFO:tensorflow:global_step/sec: 24.67
# INFO:tensorflow:loss = 0.5403604, step = 5401 (4.054 sec)
# INFO:tensorflow:global_step/sec: 24.6748
# INFO:tensorflow:loss = 0.5286176, step = 5501 (4.053 sec)
# INFO:tensorflow:global_step/sec: 24.6652
# INFO:tensorflow:loss = 0.6322115, step = 5601 (4.054 sec)
# INFO:tensorflow:global_step/sec: 24.6749
# INFO:tensorflow:loss = 0.47679722, step = 5701 (4.055 sec)
# INFO:tensorflow:global_step/sec: 24.7486
# INFO:tensorflow:loss = 0.6355563, step = 5801 (4.039 sec)
# INFO:tensorflow:global_step/sec: 24.6429
# INFO:tensorflow:loss = 0.46393257, step = 5901 (4.058 sec)
# INFO:tensorflow:global_step/sec: 24.6244
# INFO:tensorflow:loss = 0.49739665, step = 6001 (4.062 sec)
# INFO:tensorflow:global_step/sec: 24.688
# INFO:tensorflow:loss = 0.5026726, step = 6101 (4.051 sec)
# INFO:tensorflow:global_step/sec: 24.6943
# INFO:tensorflow:loss = 0.5184665, step = 6201 (4.049 sec)
# INFO:tensorflow:global_step/sec: 24.6674
# INFO:tensorflow:loss = 0.46657866, step = 6301 (4.055 sec)
# INFO:tensorflow:global_step/sec: 24.7474
# INFO:tensorflow:loss = 0.5050789, step = 6401 (4.055 sec)
# INFO:tensorflow:global_step/sec: 24.6535
# INFO:tensorflow:loss = 0.52683604, step = 6501 (4.042 sec)
# INFO:tensorflow:global_step/sec: 24.7683
# INFO:tensorflow:loss = 0.47082672, step = 6601 (4.036 sec)
# INFO:tensorflow:global_step/sec: 24.7068
# INFO:tensorflow:loss = 0.50837576, step = 6701 (4.047 sec)
# INFO:tensorflow:global_step/sec: 24.6841
# INFO:tensorflow:loss = 0.556283, step = 6801 (4.053 sec)
# INFO:tensorflow:global_step/sec: 24.7509
# INFO:tensorflow:loss = 0.45870027, step = 6901 (4.038 sec)
# INFO:tensorflow:global_step/sec: 24.6602
# INFO:tensorflow:loss = 0.51699835, step = 7001 (4.057 sec)
# INFO:tensorflow:global_step/sec: 24.7426
# INFO:tensorflow:loss = 0.47021815, step = 7101 (4.040 sec)
# INFO:tensorflow:global_step/sec: 24.3574
# INFO:tensorflow:loss = 0.54223734, step = 7201 (4.108 sec)
# INFO:tensorflow:global_step/sec: 24.4847
# INFO:tensorflow:loss = 0.50405055, step = 7301 (4.082 sec)
# INFO:tensorflow:global_step/sec: 24.4582
# INFO:tensorflow:loss = 0.48800522, step = 7401 (4.089 sec)
# INFO:tensorflow:global_step/sec: 24.2919
# INFO:tensorflow:loss = 0.5284092, step = 7501 (4.119 sec)
# INFO:tensorflow:global_step/sec: 24.3903
# INFO:tensorflow:loss = 0.4403559, step = 7601 (4.100 sec)
# INFO:tensorflow:global_step/sec: 24.4069
# INFO:tensorflow:loss = 0.44107643, step = 7701 (4.095 sec)
# INFO:tensorflow:global_step/sec: 24.4144
# INFO:tensorflow:loss = 0.33525205, step = 7801 (4.096 sec)
# INFO:tensorflow:global_step/sec: 24.3053
# INFO:tensorflow:loss = 0.46835023, step = 7901 (4.115 sec)
# INFO:tensorflow:global_step/sec: 24.4706
# INFO:tensorflow:loss = 0.4891085, step = 8001 (4.086 sec)
# INFO:tensorflow:global_step/sec: 24.3048
# INFO:tensorflow:loss = 0.44140202, step = 8101 (4.116 sec)
# INFO:tensorflow:global_step/sec: 24.3658
# INFO:tensorflow:loss = 0.3835147, step = 8201 (4.104 sec)
# INFO:tensorflow:global_step/sec: 24.3325
# INFO:tensorflow:loss = 0.38132954, step = 8301 (4.108 sec)
# INFO:tensorflow:global_step/sec: 24.4086
# INFO:tensorflow:loss = 0.35962018, step = 8401 (4.097 sec)
# INFO:tensorflow:global_step/sec: 24.2608
# INFO:tensorflow:loss = 0.52652484, step = 8501 (4.122 sec)
# INFO:tensorflow:global_step/sec: 24.4703
# INFO:tensorflow:loss = 0.47855216, step = 8601 (4.087 sec)
# INFO:tensorflow:global_step/sec: 24.2685
# INFO:tensorflow:loss = 0.45078197, step = 8701 (4.122 sec)
# INFO:tensorflow:global_step/sec: 24.2473
# INFO:tensorflow:loss = 0.45081407, step = 8801 (4.124 sec)
# INFO:tensorflow:global_step/sec: 24.5475
# INFO:tensorflow:loss = 0.50824785, step = 8901 (4.073 sec)
# INFO:tensorflow:global_step/sec: 24.516
# INFO:tensorflow:loss = 0.29569715, step = 9001 (4.095 sec)
# INFO:tensorflow:global_step/sec: 24.431
# INFO:tensorflow:loss = 0.46148807, step = 9101 (4.078 sec)
# INFO:tensorflow:global_step/sec: 24.6109
# INFO:tensorflow:loss = 0.49346057, step = 9201 (4.063 sec)
# INFO:tensorflow:global_step/sec: 24.5223
# INFO:tensorflow:loss = 0.44943622, step = 9301 (4.078 sec)
# INFO:tensorflow:global_step/sec: 24.5616
# INFO:tensorflow:loss = 0.29668128, step = 9401 (4.071 sec)
# INFO:tensorflow:global_step/sec: 24.5156
# INFO:tensorflow:loss = 0.40043563, step = 9501 (4.095 sec)
# INFO:tensorflow:global_step/sec: 24.4554
# INFO:tensorflow:loss = 0.3921821, step = 9601 (4.075 sec)
# INFO:tensorflow:global_step/sec: 24.5365
# INFO:tensorflow:loss = 0.3246025, step = 9701 (4.075 sec)
# INFO:tensorflow:global_step/sec: 24.5397
# INFO:tensorflow:loss = 0.36424455, step = 9801 (4.074 sec)
# INFO:tensorflow:global_step/sec: 24.5048
# INFO:tensorflow:loss = 0.39973882, step = 9901 (4.081 sec)
# INFO:tensorflow:Saving checkpoints for 10001 into /tmp/modelchkpt\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.43318656.

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x = {'x': eval_x},
    y = eval_y , 
    num_epochs = 1 , 
    shuffle = False
    )
eval_results = malaria_detector.evaluate(input_fn = eval_input_fn)
print(eval_results)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C169839548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C169839548>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C169839548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C169839548>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C169839548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C169839548>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C169839548>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C169839548>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C172607988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C172607988>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C172607988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C172607988>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171FAC208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171FAC208>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171FAC208>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171FAC208>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171F98508>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171F98508>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171F98508>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171F98508>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171FA0648>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171FA0648>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171FA0648>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171FA0648>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C172379348>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C172379348>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C172379348>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-24T11:56:12Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/modelchkpt\model.ckpt-10001
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-10-24-11:56:14
# INFO:tensorflow:Saving dict for global step 10001: accuracy = 0.81368583, global_step = 10001, loss = 0.39942363
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10001: /tmp/modelchkpt\model.ckpt-10001
# {'accuracy': 0.81368583, 'loss': 0.39942363, 'global_step': 10001}

# %%
pred_input_fn = tf.estimator.inputs.numpy_input_fn(
    x = {'x' : test_x},
    y = test_y,
    num_epochs = 1,
    shuffle = False
    )

y_pred = malaria_detector.predict(input_fn = pred_input_fn)
classes = [p['classes'] for p in y_pred]
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C249FB00C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C249FB00C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C249FB00C8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C249FB00C8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171EF8308>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171EF8308>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171EF8308>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171EF8308>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C249FA7A08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C249FA7A08>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C249FA7A08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C249FA7A08>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C249FA7A08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C249FA7A08>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C249FA7A08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C249FA7A08>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171F01448>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171F01448>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171F01448>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv.call of <tensorflow.python.layers.convolutional.Conv2D object at 0x000001C171F01448>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171D08EC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171D08EC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171D08EC8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Pooling2D.call of <tensorflow.python.layers.pooling.MaxPooling2D object at 0x000001C171D08EC8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C4185B7D48>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x000001C4185B7D48>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001C4185B7D48>>: AssertionError: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/modelchkpt\model.ckpt-10001
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
from sklearn.metrics import confusion_matrix , classification_report , accuracy_score
print('{} \n{} \n{}'.format(confusion_matrix(test_y , classes) , 
                           classification_report(test_y , classes) , 
                           accuracy_score(test_y , classes)))
# Out:
# [[2909 1213]
#  [ 625 4899]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.71      0.76      4122
#            1       0.80      0.89      0.84      5524
#
#     accuracy                           0.81      9646
#    macro avg       0.81      0.80      0.80      9646
# weighted avg       0.81      0.81      0.81      9646
#
# 0.809454696247149

# %%
plt.figure(1 , figsize = (15 , 9))
n = 0 
for i in range(49):
    n += 1 
    r = np.random.randint( 0  , test_x.shape[0] , 1)
    plt.subplot(7 , 7 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    plt.imshow(test_x[r[0]])
    plt.title('true {} : pred {}'.format(test_y[r[0]] , classes[r[0]]) )
    plt.xticks([]) , plt.yticks([])

plt.show()
